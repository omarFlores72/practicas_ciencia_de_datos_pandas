# %%
import pandas as pd

# %%
df_movies = pd.read_csv('IMDb movies.csv', low_memory=False)

# %%
df_rating = pd.read_csv('IMDb ratings.csv',low_memory=False)

# %%
df_movies = df_movies[['imdb_title_id', 'title', 'year', 'genre', 'country']]

# %%
df_rating = df_rating[['imdb_title_id', 'total_votes', 'mean_vote']]

# %%
#concatenacion 
df1 = pd.DataFrame ({'id': ['A', 'B', 'C', 'D'],
        'age': [30, 23, 25, 22]})
df2 = pd.DataFrame({'id': ['E', 'F', 'G', 'H'],
        'age': [40, 21, 19, 24]})

# %%
pd.concat([df1, df2], axis=0, ignore_index=True, sort=True)
# Out:
#    age id
# 0   30  A
# 1   23  B
# 2   25  C
# 3   22  D
# 4   40  E
# 5   21  F
# 6   19  G
# 7   24  H

# %%
#extraer 50% de la muestra original del dataframe (df_movies)
df_sample = df_movies.sample(frac=0.5)

# %%
df_sample.shape
# Out:
# (42928, 5)

# %%
#concatenar df_movies y df_rating
df_concat = pd.concat([df_movies, df_rating], axis=1, ignore_index=True, sort=True)
df_concat
# Out:
#                0                               1     2  \
# 0      tt0000009                      Miss Jerry  1894
# 1      tt0000574     The Story of the Kelly Gang  1906
# 2      tt0001892                  Den sorte drøm  1911
# 3      tt0002101                       Cleopatra  1912
# 4      tt0002130                       L'Inferno  1911
# ...          ...                             ...   ...
# 85850  tt9908390                         Le lion  2020
# 85851  tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852  tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853  tt9914286               Sokagin Çocuklari  2019
# 85854  tt9914942      La vida sense la Sara Amat  2019
#
#                                3                 4          5     6    7
# 0                        Romance               USA  tt0000009   154  5.9
# 1        Biography, Crime, Drama         Australia  tt0000574   589  6.3
# 2                          Drama  Germany, Denmark  tt0001892   188  6.0
# ...

# %%
#inner join dos formas de hacer lo mismo
df_movies.merge(df_rating, on='imdb_title_id')
pd.merge(df_movies, df_rating, on='imdb_title_id')
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country  total_votes  mean_vote
# 0                        Romance               USA          154        5.9
# 1        Biography, Crime, Drama         Australia          589        6.3
# ...

# %%
#outer_join (full join) #8:08:04
df1.merge(df2, on='id', how='outer')
# Out:
#   id  age_x  age_y
# 0  A   30.0    NaN
# 1  B   23.0    NaN
# 2  C   25.0    NaN
# 3  D   22.0    NaN
# 4  E    NaN   40.0
# 5  F    NaN   21.0
# 6  G    NaN   19.0
# 7  H    NaN   24.0
