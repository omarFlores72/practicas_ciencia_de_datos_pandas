# %%
import pandas as pd

# %%
df_premier = pd.read_csv('https://www.football-data.co.uk/mmz4281/2324/E0.csv')

# %%
df_premier
# Out:
#     Div        Date   Time          HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0    E0  11/08/2023  20:00           Burnley       Man City     0     3   A
# 1    E0  12/08/2023  12:30           Arsenal  Nott'm Forest     2     1   H
# 2    E0  12/08/2023  15:00       Bournemouth       West Ham     1     1   D
# 3    E0  12/08/2023  15:00          Brighton          Luton     4     1   H
# 4    E0  12/08/2023  15:00           Everton         Fulham     0     1   A
# ..   ..         ...    ...               ...            ...   ...   ...  ..
# 375  E0  19/05/2024  16:00    Crystal Palace    Aston Villa     5     0   H
# 376  E0  19/05/2024  16:00         Liverpool         Wolves     2     0   H
# 377  E0  19/05/2024  16:00             Luton         Fulham     2     4   A
# 378  E0  19/05/2024  16:00          Man City       West Ham     3     1   H
# 379  E0  19/05/2024  16:00  Sheffield United      Tottenham     0     3   A
#
# ...

# %%
#cambiar nombre de columnas
df_premier.rename(columns={'Date':'date',
                           'HomeTeam':'local',
                           'FTHG':'goles_local',
                           'FTAG':'goles_visita',}, inplace=True)

# %%
df_premier
# Out:
#     Div        date   Time             local       AwayTeam  goles_local  \
# 0    E0  11/08/2023  20:00           Burnley       Man City            0
# 1    E0  12/08/2023  12:30           Arsenal  Nott'm Forest            2
# 2    E0  12/08/2023  15:00       Bournemouth       West Ham            1
# 3    E0  12/08/2023  15:00          Brighton          Luton            4
# 4    E0  12/08/2023  15:00           Everton         Fulham            0
# ..   ..         ...    ...               ...            ...          ...
# 375  E0  19/05/2024  16:00    Crystal Palace    Aston Villa            5
# 376  E0  19/05/2024  16:00         Liverpool         Wolves            2
# 377  E0  19/05/2024  16:00             Luton         Fulham            2
# 378  E0  19/05/2024  16:00          Man City       West Ham            3
# 379  E0  19/05/2024  16:00  Sheffield United      Tottenham            0
#
#      goles_visita FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  \
# ...

# %%
#exraer multiples links
#1. crear variable raiz (root)
root = "https://www.football-data.co.uk/mmz4281"

# %%
#crear lista de ligas
leagues = ['E0', 'E1', 'E2', 'E3', 'EC']
frames = []
for league in leagues:
    for season in range(21, 23):
        url = f"{root}/{season}{season+1}/{league}.csv"
        try:
            df = pd.read_csv(url, encoding='unicode_escape')
            frames.append(df)
        except Exception as e:
            print(f"Error loading {url}: {e}")
            df.insert(1, 'season', season)

# %%
len(frames)
frames[4]
# Out:
#     Div        Date   Time      HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    EC  05/08/2023  15:00     Aldershot   Oxford City     5     2   H     3
# 1    EC  05/08/2023  15:00    Altrincham   Dag and Red     1     1   D     0
# 2    EC  05/08/2023  15:00        Barnet    Hartlepool     3     2   H     1
# 3    EC  05/08/2023  15:00  Chesterfield       Dorking     4     3   H     1
# 4    EC  05/08/2023  15:00     Gateshead  Boreham Wood     2     2   D     2
# ..   ..         ...    ...           ...           ...   ...   ...  ..   ...
# 547  EC  20/04/2024  12:15     Gateshead       Bromley     2     1   H     0
# 548  EC  20/04/2024  12:15        Oldham    Wealdstone     2     3   A     1
# 549  EC  20/04/2024  12:15      Solihull          York     1     0   H     0
# 550  EC  20/04/2024  12:15      Southend      Rochdale     1     2   A     1
# 551  EC  20/04/2024  12:15        Woking         Fylde     3     0   H     1
#
# ...

# %%
len(frames)
# Out:
# 10
