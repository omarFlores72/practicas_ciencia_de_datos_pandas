# %%
import pandas as pd

# %%
df_laptops = pd.read_csv('laptop_price.csv', encoding='latin1')

# %%
df_laptops
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
#encontrar filas con lapalabra apple en columna company
df_laptops['Company']=="Apple"
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
#filtrar dataframe basado en la condicion
df_laptops[df_laptops['Company']=="Apple"].value_counts('Company')
# Out:
# Company
# Apple    21
# Name: count, dtype: int64

# %%
df_laptops.value_counts('Company')
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# LG             3
# Google         3
# Huawei         2
# Name: count, dtype: int64

# %%
#encontrar filaes que no tienen HP en la columna company
df_laptops['Company']!="HP"
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1298     True
# 1299     True
# 1300     True
# 1301    False
# 1302     True
# Name: Company, Length: 1303, dtype: bool

# %%
#laptops con precio arriba de 2000 euros
df_laptops['Price_euros'] > 2000
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Price_euros, Length: 1303, dtype: bool

# %% [markdown]
# Crear columna basado en una condicion:np.where()

# %%
import numpy as np

# %%
#crear array basado en nivel de precio
np.where(df_laptops['Price_euros'] > 2000, 'Expensive', 'Cheap')
# Out:
# array(['Cheap', 'Cheap', 'Cheap', ..., 'Cheap', 'Cheap', 'Cheap'],
#       shape=(1303,), dtype='<U9')

# %%
#añadir nueva columna
df_laptops['price_category'] = np.where(df_laptops['Price_euros'] > 2000, 'Expensive', 'Cheap')

# %%
df_laptops.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df_laptops['Screen_size'] = np.where(df_laptops['Inches'] > 15, 'Large', 'small')

# %%
df_laptops.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df_laptops.value_counts('Screen_size')
# Out:
# Screen_size
# Large    835
# small    468
# Name: count, dtype: int64

# %%
#econtrar lapstops appple con precio > 2000 (operador and)
df_laptops[(df_laptops['Company']== 'Apple') & (df_laptops['Price_euros']>2000)] #.value_counts('Company')
# Out:
#      laptop_ID Company      Product   TypeName  Inches  \
# 3            4   Apple  MacBook Pro  Ultrabook    15.4
# 6            7   Apple  MacBook Pro  Ultrabook    15.4
# 12          13   Apple  MacBook Pro  Ultrabook    15.4
# 17          18   Apple  MacBook Pro  Ultrabook    15.4
# 249        254   Apple  MacBook Pro  Ultrabook    13.3
#
#                        ScreenResolution                   Cpu   Ram  \
# 3    IPS Panel Retina Display 2880x1800  Intel Core i7 2.7GHz  16GB
# 6    IPS Panel Retina Display 2880x1800  Intel Core i7 2.2GHz  16GB
# 12   IPS Panel Retina Display 2880x1800  Intel Core i7 2.8GHz  16GB
# 17   IPS Panel Retina Display 2880x1800  Intel Core i7 2.9GHz  16GB
# 249  IPS Panel Retina Display 2560x1600  Intel Core i5 3.1GHz   8GB
#
#                   Memory                           Gpu     OpSys  Weight  \
# 3              512GB SSD            AMD Radeon Pro 455     macOS  1.83kg
# 6    256GB Flash Storage       Intel Iris Pro Graphics  Mac OS X  2.04kg
# ...

# %%
#condicion or
df_laptops[((df_laptops['Company']== 'Apple')) | (df_laptops['Company']== 'Lenovo') & (df_laptops['Price_euros']>2000)].value_counts('Company')
# Out:
# Company
# Lenovo    32
# Apple     21
# Name: count, dtype: int64

# %% [markdown]
# CREAR COLUMNA CONDICIONAL CON 1 O MAS OPCIONES

# %%
import numpy as np

# %%
#crear array basado en multiples niveles de precio 
#crear condiciones y valores
condiciones = [
    df_laptops['Price_euros']>3000,
    (df_laptops['Price_euros']>2000) & (df_laptops['Price_euros']<=3000),
    (df_laptops['Price_euros']>800) & (df_laptops['Price_euros']<=2000),
    df_laptops['Price_euros']<=800
]
valores = ['Muy caro', 'Caro', 'barato', 'Muy Barato']

# %%
df_laptops['Niveles_precio'] = np.select(condiciones, valores, default='Sin categoría')

# %%
df_laptops
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df_laptops.value_counts('Niveles_precio')
# Out:
# Niveles_precio
# barato        655
# Muy Barato    511
# Caro          118
# Muy caro       19
# Name: count, dtype: int64

# %%
#array de tamaño pantalla muy grande>16, grande>14, pequeño>12, muy pequeño<12 
condiciones = [
    df_laptops['Inches']>16,
    (df_laptops['Inches']>14) & (df_laptops['Inches']<=16),
    (df_laptops['Inches']>14) & (df_laptops['Inches']<=12),
    df_laptops['Inches']<=12
]
valores = ['Muy grande', 'Grande', 'pequeño', 'Muy pequeño']

# %%
df_laptops['Nivel_tamaño'] = np.select(condiciones, valores, default='Sin categoría')

# %%
df_laptops.value_counts('Nivel_tamaño')
# Out:
# Nivel_tamaño
# Grande           674
# Sin categoría    419
# Muy grande       166
# Muy pequeño       44
# Name: count, dtype: int64

# %% [markdown]
# FILTRADO SIMPLE

# %%
#SELECCIONAR APPLE O HP metodo is in
df_laptops['Company'].isin(['apple', 'HP'])
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301     True
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
#filtrar dataframe
df_laptops[df_laptops['Company'].isin(['apple', 'HP'])]
# Out:
#       laptop_ID Company                                  Product   TypeName  \
# 2             3      HP                                   250 G6   Notebook
# 10           11      HP                                   250 G6   Notebook
# 11           12      HP                                   250 G6   Notebook
# 22           23      HP                                   255 G6   Notebook
# 24           25      HP  15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)  Ultrabook
# ...         ...     ...                                      ...        ...
# 1282       1300      HP                         Stream 11-Y000na    Netbook
# 1287       1305      HP      15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1294       1312      HP                      Pavilion 15-AW003nv   Notebook
# 1296       1314      HP                         Stream 11-Y000na    Netbook
# 1301       1319      HP      15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
#
# ...

# %%
#ecnontrar notebooks o ultrabooks
filtro1 = df_laptops['TypeName'].isin(['Notebook', 'Ultrabook'])
filtro2 = df_laptops['Company'].isin(['Apple','HP'])

# %%
df_laptops [filtro1 & filtro2].value_counts('TypeName')
# Out:
# TypeName
# Notebook     184
# Ultrabook     57
# Name: count, dtype: int64

# %% [markdown]
# ECONTRAR DUPLICADOS

# %%
duplicated = df_laptops.duplicated(['Product', 'TypeName', 'Inches'])

# %%
df_laptops[duplicated].sort_values(['Product', 'TypeName'])
# Out:
#       laptop_ID Company                              Product  \
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1098       1113      HP                               250 G5
# 1170       1188      HP                               250 G5
# 10           11      HP                               250 G6
# ...         ...     ...                                  ...
# 414         421    Asus                         ZenBook Flip
# 826         835    Asus                         ZenBook Flip
# 1275       1293    Asus                 ZenBook UX305CA-UBM1
# 1289       1307    Asus                 ZenBook UX305CA-UBM1
# 676         684    Asus                            Zenbook 3
#
#                 TypeName  Inches                           ScreenResolution  \
# 1287            Notebook    15.6                                   1366x768
# 1301            Notebook    15.6                                   1366x768
# ...

# %%
#ordenar dataframeascendente por "company" y "price"
#mas barato primero y mas caro al ultimo
df_laptops = df_laptops.sort_values(['Company', 'Price_euros'])
df_laptops
# Out:
#       laptop_ID Company                           Product   TypeName  Inches  \
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome    Netbook    11.6
# 290         295    Acer              Chromebook C910-C2ST   Notebook    15.6
# 1102       1117    Acer                     Chromebook 15   Notebook    15.6
# 695         703    Acer                 TravelMate B117-M    Netbook    11.6
# 1198       1216    Acer                          Aspire 3   Notebook    15.6
# ...         ...     ...                               ...        ...     ...
# 191         195    Vero     K147 (N3350/4GB/32GB/FHD/W10)   Notebook    14.0
# 877         888  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 192         196  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 184         188  Xiaomi                       Mi Notebook   Notebook    15.6
# 514         521  Xiaomi                       Mi Notebook   Notebook    15.6
#
# ...

# %%
#revisar todas las categorias en "company"
df_laptops.value_counts('Company')
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# LG             3
# Google         3
# Huawei         2
# Name: count, dtype: int64

# %%
#por defecto keep='first
duplicated_fisrt = df_laptops.duplicated('Company')

# %%
df_laptops[duplicated_fisrt]
#valores no duplicados 
df_laptops[~duplicated_fisrt]
# Out:
#       laptop_ID    Company                           Product   TypeName  \
# 1215       1233       Acer  C740-C9QX (3205U/2GB/32GB/Chrome    Netbook
# 1             2      Apple                       Macbook Air  Ultrabook
# 20           21       Asus                   Vivobook E200HA    Netbook
# 30           31      Chuwi                     LapBook 15.6"   Notebook
# 340         346       Dell                     Inspiron 3552   Notebook
# 983         997    Fujitsu                     LifeBook A556   Notebook
# 472         479     Google                   Pixelbook (Core  Ultrabook
# 1268       1286         HP                  Stream 11-Y000na    Netbook
# 170         174     Huawei                        MateBook X  Ultrabook
# 909         922         LG                       Gram 14Z970  Ultrabook
# 1272       1290     Lenovo                IdeaPad 100S-14IBR   Notebook
# 1169       1187        MSI                          PL60 7RD     Gaming
# ...

# %%
#eliminar duplicados en 2 o mas columnas
df_laptops.drop_duplicates(['Company'])[['Company', 'Price_euros']]
# Out:
#         Company  Price_euros
# 1215       Acer       174.00
# 1         Apple       898.94
# 20         Asus       191.90
# 30        Chuwi       244.99
# 340        Dell       274.90
# 983     Fujitsu       649.00
# 472      Google      1275.00
# 1268         HP       209.00
# 170      Huawei      1349.00
# 909          LG      1899.00
# 1272     Lenovo       229.00
# 1169        MSI       839.00
# 626    Mediacom       239.00
# 457   Microsoft       989.00
# 1117      Razer      1029.00
# 430     Samsung       269.00
# 159     Toshiba       447.00
# 1120       Vero       196.00
# 877      Xiaomi       935.00

# %%
#mas barato. inplace guarda los daos en lugar de arrojar una copia
df_laptops.drop_duplicates(['Company'], keep='last',inplace=True, ignore_index=True)
df_laptops[['Company', 'Price_euros']]
# Out:
#       Company  Price_euros
# 0        Acer      2599.00
# 1       Apple      2858.00
# 2        Asus      3975.00
# 3       Chuwi       449.00
# 4        Dell      3659.40
# 5     Fujitsu       799.00
# 6      Google      2199.00
# 7          HP      4389.00
# 8      Huawei      1499.00
# 9          LG      2299.00
# 10     Lenovo      4899.00
# 11        MSI      2799.00
# 12   Mediacom       389.00
# 13  Microsoft      2589.00
# 14      Razer      6099.00
# 15    Samsung      1849.00
# 16    Toshiba      2799.00
# 17       Vero       260.00
# 18     Xiaomi      1399.95

# %%
#ordenar por compalia e inches mas pequeños primero y mas grandes al final
df_laptops.drop_duplicates(['Inches'], keep='last')[['Company', 'Inches']]
# Out:
#      Company  Inches
# 0      Apple    15.4
# 1     Google    12.3
# 2     Huawei    13.0
# 3        MSI    18.4
# 4  Microsoft    13.5
# 5      Razer    17.3
# 6    Samsung    15.0
# 7    Toshiba    13.3
# 8       Vero    14.0
# 9     Xiaomi    15.6

# %% [markdown]
# METODO UNIQUE. DEVOLVER VALORES UNICOS DE UNA SERIE

# %%
#OBTENERELEMENTOS UNICOS DE LA COLUMNA COMPANY
len(df_laptops['Company'].unique())
# Out:
# 10

# %%
len(df_laptops['Inches'].unique())
# Out:
# 10
