# %%
import pandas as pd
import numpy as np

# %%
data = np.array([[2,4], [6,8], [10,12]])

# %%
df = pd.DataFrame(data, index=['row1', 'row2', 'row3'],
            columns=['col1', 'col2'])

# %%
df_examen = pd.read_csv('/home/omar/pandas/csv/StudentsPerformance.csv')

# %%
df_examen.shape
# Out:
# (1000, 8)

# %%
#atributos. index
df_examen.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_examen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df_examen.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#tamaño del dataframe
len(df_examen)
# Out:
# 1000

# %%
#redondear
round(df_examen, 2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
type(df_examen['gender'])
# Out:
# pandas.core.series.Series

# %%
df_examen['gender'].tail(12)
# Out:
# 988    female
# 989    female
# 990      male
# 991    female
# 992    female
# 993    female
# 994      male
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, dtype: object

# %%
df_examen[['gender', 'math score', 'writing score']]
# Out:
#      gender  math score  writing score
# 0    female          72             74
# 1    female          69             88
# 2    female          90             93
# 3      male          47             44
# 4      male          76             75
# ..      ...         ...            ...
# 995  female          88             95
# 996    male          62             55
# 997  female          59             65
# 998  female          68             77
# 999  female          77             86
#
# [1000 rows x 3 columns]

# %%
#agregar nueva columna
df_examen[['language score']] = 80
df_examen
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#crear un array de 1000 elementos
language_score = np.arange(0, 1000)

# %%
#agregar nueva columna al dataframe con un array
df_examen['language score'] = language_score
df_examen
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#numeros enteros aleatorios
int_language_score = np.random.randint(50, 100, size=1000)
int_language_score
# Out:
# array([55, 82, 69, 92, 66, 62, 59, 73, 70, 84, 76, 86, 70, 92, 68, 56, 60,
#        54, 73, 83, 91, 83, 63, 65, 60, 94, 97, 81, 94, 63, 70, 91, 51, 93,
#        75, 88, 54, 86, 81, 52, 98, 68, 99, 81, 86, 53, 60, 99, 67, 80, 93,
#        71, 62, 76, 78, 72, 64, 98, 79, 92, 64, 56, 68, 65, 55, 58, 94, 84,
#        60, 99, 76, 56, 77, 88, 62, 53, 67, 82, 91, 76, 81, 96, 62, 65, 80,
#        54, 85, 61, 68, 62, 85, 78, 59, 77, 96, 90, 93, 69, 72, 61, 68, 94,
#        95, 68, 51, 87, 88, 53, 59, 90, 69, 70, 58, 65, 83, 63, 99, 68, 55,
#        79, 95, 57, 74, 97, 79, 76, 88, 75, 98, 68, 53, 59, 70, 79, 68, 76,
#        89, 87, 53, 83, 84, 83, 96, 83, 90, 60, 80, 97, 60, 61, 62, 54, 60,
#        63, 78, 62, 53, 57, 84, 99, 88, 78, 66, 53, 75, 90, 71, 63, 70, 66,
#        55, 96, 57, 65, 54, 71, 65, 94, 75, 50, 75, 56, 61, 64, 83, 60, 84,
#        61, 80, 90, 71, 91, 68, 50, 52, 87, 89, 58, 54, 87, 81, 94, 97, 96,
# ...

# %%
#elminomo valor es inclusivo y el maximo exclusivo
min(int_language_score)
max(int_language_score)
# Out:
# np.int64(99)

# %%
#nueva columna al dataframe con un array
df_examen['language_score'] = int_language_score

# %%
#operaciones con dataframe
df_examen['math score'].sum()
# Out:
# np.int64(66089)

# %%
#contar, promedio, sev estandar, maximo, minimo
df_examen['math score'].count()
df_examen['math score'].mean()
df_examen['math score'].std()
df_examen['math score'].max()
df_examen['math score'].min()
# Out:
# np.int64(0)

# %%
df_examen.describe()
#tosos los resultrados de las columnas numericas
# Out:
#        math score  reading score  writing score  language score  \
# count  1000.00000    1000.000000    1000.000000     1000.000000
# mean     66.08900      69.169000      68.054000      499.500000
# std      15.16308      14.600192      15.195657      288.819436
# min       0.00000      17.000000      10.000000        0.000000
# 25%      57.00000      59.000000      57.750000      249.750000
# 50%      66.00000      70.000000      69.000000      499.500000
# 75%      77.00000      79.000000      79.000000      749.250000
# max     100.00000     100.000000     100.000000      999.000000
#
#        language_score
# count     1000.000000
# mean        74.147000
# std         14.015271
# min         50.000000
# 25%         62.000000
# 50%         73.000000
# 75%         86.250000
# max         99.000000

# %%
#calcular ahora en filas
df_examen['average'] = (df_examen['math score'] + df_examen['reading score'] + df_examen['writing score'])/3
#df_examen

# %%
#contar elementos por categoria en este caso gender
len(df_examen['gender'])
#metodo count
df_examen['gender'].count()
# Out:
# np.int64(1000)

# %%
#contar por categoria solo hasta value_counts() lo de normalize es para el porcent
df_examen['gender'].value_counts(normalize=True).sort_values(ascending=True)
# Out:
# gender
# male      0.482
# female    0.518
# Name: proportion, dtype: float64

# %%
df_examen['race/ethnicity'].sort_values(ascending=True
                                        , key=lambda col:col.str.lower())
# Out:
# 778    group A
# 546    group A
# 820    group A
# 741    group A
# 305    group A
#         ...
# 297    group E
# 293    group E
# 289    group E
# 206    group E
# 499    group E
# Name: race/ethnicity, Length: 1000, dtype: object
